# %%
# Data Visualization II
# 1. Use the inbuilt dataset 'titanic' as used in the above problem. Plot a box plot for distribution
# of age with respect to each gender along with the information about whether they survived
# or not. (Column names : 'sex' and 'age')
# 2. Write observations on the inference from the above statistics.

# %%
import seaborn as sns

# %%
df = sns.load_dataset('titanic')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
x1 = df.dropna()

# %%
x1.isnull().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# deck           0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %%
sns.boxplot(x='sex',y='age',data=x1)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='age'>

# %%
sns.boxplot(x='sex',y='age',hue='survived',data=x1)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='age'>

# %%
x1.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  182.000000  182.000000  182.000000  182.000000  182.000000  182.000000
# mean     0.675824    1.192308   35.623187    0.467033    0.478022   78.919735
# std      0.469357    0.516411   15.671615    0.645007    0.755869   76.490774
# min      0.000000    1.000000    0.920000    0.000000    0.000000    0.000000
# 25%      0.000000    1.000000   24.000000    0.000000    0.000000   29.700000
# 50%      1.000000    1.000000   36.000000    0.000000    0.000000   57.000000
# 75%      1.000000    1.000000   47.750000    1.000000    1.000000   90.000000
# max      1.000000    3.000000   80.000000    3.000000    4.000000  512.329200

# %%
#when the data from titanic dataset was analysed and boxplots were plotted comparing age,sex
#and if they survived or not; it is found that passengers included babies which were 9 months old
#to people having age upto 80 years.Most of the women(around 50%) which did not survived had age from 10 to 45
#while the women which did survived lied into age group of 25 to 40.Accoring to boxplot young women on the boat
#did survived. while with men most men(50%) had age between 35 to 55 which survived and 28 to 40 which did survived
#Among men which did not survived youngest were around 20 which which did not survived were around 9months.

# %%
sns.boxplot(x='embarked',y='age',data=x1)
# Out:
# <AxesSubplot:xlabel='embarked', ylabel='age'>

# %%
sns.boxplot(x='pclass',y='age',hue='sex',data=x1)
# Out:
# <AxesSubplot:xlabel='pclass', ylabel='age'>

# %%
sns.boxplot(x='embarked',y='age',hue='survived',data=x1)
# Out:
# <AxesSubplot:xlabel='embarked', ylabel='age'>

# %%
sns.violinplot(x='age',y='sex',data=x1)
# Out:
# <AxesSubplot:xlabel='age', ylabel='sex'>

# %%
sns.violinplot(x='age',y='sex',hue='survived',data=x1)
# Out:
# <AxesSubplot:xlabel='age', ylabel='sex'>

# %%
sns.stripplot(x='age',y='sex',data=x1)
# Out:
# <AxesSubplot:xlabel='age', ylabel='sex'>

# %%
sns.stripplot(x='age',y='sex',hue='survived',data=x1)
# Out:
# <AxesSubplot:xlabel='age', ylabel='sex'>

# %%
sns.stripplot(x='age',y='sex',hue='survived',data=x1,dodge=True)
# Out:
# <AxesSubplot:xlabel='age', ylabel='sex'>

# %%
sns.stripplot(x='sex',y='age',dodge=True,data=df,hue='survived')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='age'>

# %%
sns.swarmplot(x='age',y='sex',hue='survived',data=x1)
# Out:
# <AxesSubplot:xlabel='age', ylabel='sex'>

# %%
sns.swarmplot(x='age',y='sex',hue='survived',data=x1,dodge=True)
# Out:
# <AxesSubplot:xlabel='age', ylabel='sex'>
